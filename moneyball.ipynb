# %% [markdown]
# # Moneyball

# %% [markdown]
# # The Squad
#
# Player stats from 1986 made the most appearances on the all time team, so that year was selected for the moneyball one year team.
#
# 1986
# * Pitcher- Steve Carlton
# * Catcher- John Mizerock
# * 1st Baseman- Lee Mazzilli
# * 2nd Baseman- Barry Larkin
# * 3rd Baseman- Cory Snyder
# * Short Stop- Robby Thompson
# * Left Field- Kal Daniels
# * Center Field- Reggie Williams
# * Right Field- Mike Greenwell
#
# All Time
# * Pitcher- Bob Knepper
# * Catcher- John Mizerock
# * 1st Baseman- Lee Mazzilli
# * 2nd Baseman- Keith Miller
# * 3rd Baseman- Dave Magadan
# * Short Stop- Jody Reed
# * Left Field- John Kruk
# * Center Field- Tracy Jones
# * Right Field- Dave Martinez

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re

# %matplotlib inline

# %% [markdown]
# OBP = (H + BB + HBP)/(AB + BB + HBP + SF)

# %%
salaries = pd.read_csv('data/salaries.csv')

# %%
batting = pd.read_csv('data/batting.csv')

# %%
fielding = pd.read_csv('data/fielding.csv')

# %%
master = pd.read_csv('data/master.csv')

# %%
salaries.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
batting.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...     0   0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...    13   8
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...    19   3
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...    27   1
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...    16   6
#
#    CS  BB  SO  IBB  HBP  SH  SF  GIDP
# 0   0   0   0  NaN  NaN NaN NaN   NaN
# 1   1   4   0  NaN  NaN NaN NaN   NaN
# 2   1   2   5  NaN  NaN NaN NaN   NaN
# 3   1   0   2  NaN  NaN NaN NaN   NaN
# 4   2   2   1  NaN  NaN NaN NaN   NaN
#
# [5 rows x 22 columns]

# %%
stats = batting[['playerID', 'yearID','H', 'BB', 'HBP', 'AB', 'SF']]

# %%
stats.head()
# Out:
#     playerID  yearID   H  BB  HBP   AB  SF
# 0  abercda01    1871   0   0  NaN    4 NaN
# 1   addybo01    1871  32   4  NaN  118 NaN
# 2  allisar01    1871  40   2  NaN  137 NaN
# 3  allisdo01    1871  44   0  NaN  133 NaN
# 4  ansonca01    1871  39   2  NaN  120 NaN

# %%
fielding.head()
# Out:
#     playerID  yearID  stint teamID lgID POS   G  GS  InnOuts  PO   A   E  DP  \
# 0  abercda01    1871      1    TRO  NaN  SS   1 NaN      NaN   1   3   2   0
# 1   addybo01    1871      1    RC1  NaN  2B  22 NaN      NaN  67  72  42   5
# 2   addybo01    1871      1    RC1  NaN  SS   3 NaN      NaN   8  14   7   0
# 3  allisar01    1871      1    CL1  NaN  2B   2 NaN      NaN   1   4   0   0
# 4  allisar01    1871      1    CL1  NaN  OF  29 NaN      NaN  51   3   7   1
#
#    PB  WP  SB  CS  ZR
# 0 NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN
# 2 NaN NaN NaN NaN NaN
# 3 NaN NaN NaN NaN NaN
# 4 NaN NaN NaN NaN NaN

# %%
position = fielding[['playerID', 'yearID', 'POS', 'G']]

# %%
position.head()
# Out:
#     playerID  yearID POS   G
# 0  abercda01    1871  SS   1
# 1   addybo01    1871  2B  22
# 2   addybo01    1871  SS   3
# 3  allisar01    1871  2B   2
# 4  allisar01    1871  OF  29

# %%
name_data = master[['playerID', 'nameFirst', 'nameLast']]

# %%
name_data.head()
# Out:
#     playerID nameFirst nameLast
# 0  aardsda01     David  Aardsma
# 1  aaronha01      Hank    Aaron
# 2  aaronto01    Tommie    Aaron
# 3   aasedo01       Don     Aase
# 4   abadan01      Andy     Abad

# %%
all_stats = pd.merge(position, stats)

# %%
all_stats.head()
# Out:
#     playerID  yearID POS   G   H  BB  HBP   AB  SF
# 0  abercda01    1871  SS   1   0   0  NaN    4 NaN
# 1   addybo01    1871  2B  22  32   4  NaN  118 NaN
# 2   addybo01    1871  SS   3  32   4  NaN  118 NaN
# 3  allisar01    1871  2B   2  40   2  NaN  137 NaN
# 4  allisar01    1871  OF  29  40   2  NaN  137 NaN

# %%
all_stats_salary = pd.merge(all_stats, salaries)

# %%
all_stats_salary.head()
# Out:
#     playerID  yearID POS   G   H  BB  HBP   AB  SF teamID lgID  salary
# 0  ackerji01    1985   P  61 NaN NaN  NaN  NaN NaN    TOR   AL  170000
# 1  agostju01    1985   P  54   0   0    0    0   0    CHA   AL  147500
# 2  aguaylu01    1985  2B  17  46  22    6  165   3    PHI   NL  237000
# 3  aguaylu01    1985  3B   7  46  22    6  165   3    PHI   NL  237000
# 4  aguaylu01    1985  SS  60  46  22    6  165   3    PHI   NL  237000

# %%
stats_salary_name = pd.merge(name_data, all_stats_salary)

# %%
stats_salary_name.head()
# Out:
#     playerID nameFirst nameLast  yearID POS   G  H  BB  HBP  AB  SF teamID  \
# 0  aardsda01     David  Aardsma    2004   P  11  0   0    0   0   0    SFN
# 1  aardsda01     David  Aardsma    2007   P  25  0   0    0   0   0    CHA
# 2  aardsda01     David  Aardsma    2008   P  47  0   0    0   1   0    BOS
# 3  aardsda01     David  Aardsma    2009   P  73  0   0    0   0   0    SEA
# 4  aardsda01     David  Aardsma    2010   P  53  0   0    0   0   0    SEA
#
#   lgID   salary
# 0   NL   300000
# 1   AL   387500
# 2   AL   403250
# 3   AL   419000
# 4   AL  2750000

# %%
stats_salary_name['OBP'] = (stats_salary_name['H']+stats_salary_name['BB']+stats_salary_name['HBP'])/(stats_salary_name['AB']+stats_salary_name['BB']+stats_salary_name['HBP']+stats_salary_name['SF'])

# %%
stats_salary_name.head()
# Out:
#     playerID nameFirst nameLast  yearID POS   G  H  BB  HBP  AB  SF teamID  \
# 0  aardsda01     David  Aardsma    2004   P  11  0   0    0   0   0    SFN
# 1  aardsda01     David  Aardsma    2007   P  25  0   0    0   0   0    CHA
# 2  aardsda01     David  Aardsma    2008   P  47  0   0    0   1   0    BOS
# 3  aardsda01     David  Aardsma    2009   P  73  0   0    0   0   0    SEA
# 4  aardsda01     David  Aardsma    2010   P  53  0   0    0   0   0    SEA
#
#   lgID   salary  OBP
# 0   NL   300000  NaN
# 1   AL   387500  NaN
# 2   AL   403250    0
# 3   AL   419000  NaN
# 4   AL  2750000  NaN

# %%
stats_salary_name.sort('OBP', ascending=False)
# Out:
#         playerID nameFirst     nameLast  yearID POS   G   H  BB  HBP  AB  SF  \
# 59221    yanes01   Esteban          Yan    2003   P  39   1   0    0   1   0
# 34934  martipe03     Pedro     Martinez    1995   P  25   0   1    0   0   0
# 13960  deweyma01      Mark        Dewey    1993   P  21   0   1    0   0   0
# 54582  tupmama01      Matt       Tupman    2008   C   1   1   0    0   1   0
# 4012   bennega01      Gary      Bennett    2001   C  19   1   0    0   1   0
# 48723  saundto01      Tony     Saunders    1998   P  31   2   0    0   2   0
# 39129  musseje01      Jeff    Musselman    1989   P  20   0   1    0   0   0
# 47020  rogeres01     Esmil       Rogers    2012   P  23   1   0    0   1   0
# 47022  rogeres01     Esmil       Rogers    2012   P  44   1   0    0   1   0
# 7731   burnese01      Sean      Burnett    2011   P  69   1   1    0   1   0
# 39127  musseje01      Jeff    Musselman    1989   P   5   0   1    0   0   0
# ...

# %%
twenty_ab = stats_salary_name['AB'] >= 25

# %%
twenty_ab = stats_salary_name[twenty_ab]

# %%
twenty_ab.sort('OBP', ascending=False).head()
# Out:
#         playerID nameFirst  nameLast  yearID POS    G    H   BB  HBP   AB  SF  \
# 5385   bondsba01     Barry     Bonds    2004  LF  133  135  232    9  373   3
# 5386   bondsba01     Barry     Bonds    2004  OF  133  135  232    9  373   3
# 5381   bondsba01     Barry     Bonds    2002  LF  135  149  198    9  403   2
# 5382   bondsba01     Barry     Bonds    2002  OF  135  149  198    9  403   2
# 37516  millira01     Randy  Milligan    1993  1B   18   20   14    0   47   0
#
#       teamID lgID    salary       OBP
# 5385     SFN   NL  18000000  0.609400
# 5386     SFN   NL  18000000  0.609400
# 5381     SFN   NL  15000000  0.581699
# 5382     SFN   NL  15000000  0.581699
# 37516    CIN   NL    635000  0.557377

# %%
all_data = twenty_ab.copy()

# %%
all_data['OBP/salary'] = twenty_ab['OBP']/twenty_ab['salary']

# %%
all_data.sort(['OBP/salary'], ascending=False)
# Out:
#         playerID nameFirst    nameLast  yearID POS    G    H  BB  HBP   AB  \
# 27346  jamesdi01      Dion       James    1993  CF   14  114  31    2  343
# 27347  jamesdi01      Dion       James    1993  DH    1  114  31    2  343
# 27350  jamesdi01      Dion       James    1993  RF    1  114  31    2  343
# 27349  jamesdi01      Dion       James    1993  OF  103  114  31    2  343
# 27348  jamesdi01      Dion       James    1993  LF   91  114  31    2  343
# 27345  jamesdi01      Dion       James    1993  1B    1  114  31    2  343
# 35603  mazzile01       Lee    Mazzilli    1986  1B    8   16  12    2   58
# 35627  mazzile01       Lee    Mazzilli    1986  RF    2   16  12    2   58
# 35607  mazzile01       Lee    Mazzilli    1986  CF    3   16  12    2   58
# 35611  mazzile01       Lee    Mazzilli    1986  LF   16   16  12    2   58
# 35615  mazzile01       Lee    Mazzilli    1986  LF    8   16  12    2   58
# ...

# %%
final_data = all_data[['playerID', 'nameFirst','nameLast', 'yearID', 'POS', 'salary', 'OBP', 'OBP/salary']]

# %%
final_data = final_data.sort(['OBP/salary'], ascending=False)

# %%
final_data
# Out:
#         playerID nameFirst    nameLast  yearID POS    salary       OBP  \
# 27346  jamesdi01      Dion       James    1993  CF         0  0.389920
# 27347  jamesdi01      Dion       James    1993  DH         0  0.389920
# 27350  jamesdi01      Dion       James    1993  RF         0  0.389920
# 27349  jamesdi01      Dion       James    1993  OF         0  0.389920
# 27348  jamesdi01      Dion       James    1993  LF         0  0.389920
# 27345  jamesdi01      Dion       James    1993  1B         0  0.389920
# 35603  mazzile01       Lee    Mazzilli    1986  1B     60000  0.416667
# 35627  mazzile01       Lee    Mazzilli    1986  RF     60000  0.416667
# 35607  mazzile01       Lee    Mazzilli    1986  CF     60000  0.416667
# 35611  mazzile01       Lee    Mazzilli    1986  LF     60000  0.416667
# 35615  mazzile01       Lee    Mazzilli    1986  LF     60000  0.416667
# 35619  mazzile01       Lee    Mazzilli    1986  OF     60000  0.416667
# ...

# %%
x = final_data['salary'] > 0

# %%
the_squad = final_data[x]

# %%
the_squad = the_squad.drop_duplicates(['playerID'])

# %%
the_squad = the_squad.drop_duplicates(['POS'])

# %%
the_squad
# Out:
#         playerID nameFirst   nameLast  yearID POS  salary       OBP  \
# 35603  mazzile01       Lee   Mazzilli    1986  1B   60000  0.416667
# 30421   krukjo01      John       Kruk    1986  OF   60000  0.403077
# 20672  greenmi01      Mike  Greenwell    1986  RF   60000  0.400000
# 12645  danieka01       Kal    Daniels    1986  LF   60000  0.398058
# 37388  milleke01     Keith     Miller    1987  2B   62500  0.407407
# 37714  mizerjo01      John   Mizerock    1986   C   60000  0.373832
# 33930  magadda01      Dave    Magadan    1987  3B   62500  0.386047
# 36272  mcgrifr01      Fred    McGriff    1987  DH   62500  0.376404
# 34683  martida01      Dave   Martinez    1987  CF   62500  0.371869
# 45504   reedjo01      Jody       Reed    1988  SS   64500  0.380463
# 30039  kneppbo01       Bob    Knepper    1989   P   68000  0.351351
#
#        OBP/salary
# 35603    0.000007
# 30421    0.000007
# 20672    0.000007
# 12645    0.000007
# 37388    0.000007
# 37714    0.000006
# ...

# %%
the_squad86 = final_data[x]

# %%
the_squad86 = the_squad86[the_squad86.yearID == 1986]

# %%
the_squad86 = the_squad86.drop_duplicates(['playerID'])

# %%
the_squad86 = the_squad86.drop_duplicates(['POS'])

# %%
the_squad86
# Out:
#         playerID nameFirst   nameLast  yearID POS  salary       OBP  \
# 35603  mazzile01       Lee   Mazzilli    1986  1B   60000  0.416667
# 30421   krukjo01      John       Kruk    1986  OF   60000  0.403077
# 20672  greenmi01      Mike  Greenwell    1986  RF   60000  0.400000
# 12645  danieka01       Kal    Daniels    1986  LF   60000  0.398058
# 37714  mizerjo01      John   Mizerock    1986   C   60000  0.373832
# 42107  pasquda01       Dan     Pasqua    1986  DH   70000  0.398792
# 58155  willire01    Reggie   Williams    1986  CF   60000  0.331307
# 53850  thompro01     Robby   Thompson    1986  SS   60000  0.328308
# 30970  larkiba01     Barry     Larkin    1986  2B   60000  0.319527
# 50897  snydeco02      Cory     Snyder    1986  3B   60000  0.298611
# 8977   carltst01     Steve    Carlton    1986   P   60000  0.228571
#
#        OBP/salary
# 35603    0.000007
# 30421    0.000007
# 20672    0.000007
# 12645    0.000007
# 37714    0.000006
# 42107    0.000006
# ...

# %%
the_squad14 = final_data[x]

# %%
the_squad14 = the_squad14[the_squad14.yearID == 2014]

# %%
the_squad14 = the_squad14.drop_duplicates(['playerID'])

# %%
the_squad14 = the_squad14.drop_duplicates(['POS'])

# %%
the_squad14
# Out:
#         playerID  nameFirst    nameLast  yearID POS  salary       OBP  \
# 56887  weeksje01     Jemile       Weeks    2014  2B  515000  0.406250
# 55166  vanslsc01      Scott   Van Slyke    2014  OF  507500  0.386179
# 14139  dickeco01      Corey   Dickerson    2014  LF  500000  0.364017
# 59249  yelicch01  Christian      Yelich    2014  CF  505000  0.362253
# 40228  norride01      Derek      Norris    2014   C  505000  0.360544
# 14311  donaljo02       Josh   Donaldson    2014  3B  500000  0.342446
# 23016  harrijo05       Josh    Harrison    2014  SS  513000  0.346715
# 24699  hicksaa01      Aaron       Hicks    2014  RF  507500  0.340807
# 10146  chiselo01     Lonnie  Chisenhall    2014  1B  510800  0.342803
# 34174  maldoma01     Martin   Maldonado    2014   P  502000  0.320000
#
#          OBP/salary
# 56887  7.888350e-07
# 55166  7.609436e-07
# 14139  7.280335e-07
# 59249  7.173320e-07
# 40228  7.139489e-07
# 14311  6.848921e-07
# 23016  6.758583e-07
# 24699  6.715412e-07
# ...
